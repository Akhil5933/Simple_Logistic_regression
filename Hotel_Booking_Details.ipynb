# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %%
#importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the file for analysis
ds=pd.read_csv(r"C:\Users\akhil\Downloads\dsp_45_mock_assessment_akilesh\dsp_45_mock_assessment_akilesh\hotel_booking_details.csv")

# %%
#it shows by default top 5 rows
ds.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  INFLATION  \
# 0                        0                     0       2  ...        1.8
# ...

# %%
#it shows how many rows and columns are present in the data
ds.shape
# Out:
# (119390, 43)

# %%
#as the columns are more and overlapping and the data in the file we were unable to see, to make it visible we set maximum columns.
pd.set_option('display.max.columns',43)

# %%
# we can see all columns without overlapping for first fiv rows
ds.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
#we need to analyse the data or lookup to take further decisions,as it is a big data we have make it or visible to see for 100 samples for analysing data.
pd.set_option('display.max.rows',100)
ds.head()
ds.sample(100)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 117258    City Hotel            0         68               2017
# 76928     City Hotel            1        342               2015
# 110492    City Hotel            0         97               2017
# 47533     City Hotel            1         16               2016
# 17702   Resort Hotel            0        287               2015
# 70474     City Hotel            1        150               2017
# 76358     City Hotel            0        273               2015
# 98225     City Hotel            0         19               2016
# 26198   Resort Hotel            0         50               2016
# 79763     City Hotel            0         11               2015
# 67366     City Hotel            1        124               2017
# 114459    City Hotel            0         26               2017
# 28023   Resort Hotel            0        327               2016
# 19349   Resort Hotel            1         30               2016
# ...

# %%
#for displaying the columns of the data
ds.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'MO_YR', 'CPI_AVG',
#        'INFLATION', 'INFLATION_CHG', 'CSMR_SENT', 'UNRATE', 'INTRSRT', 'GDP',
#        'FUEL_PRCS', 'CPI_HOTELS', 'US_GINI', 'DIS_INC'],
#       dtype='object')

# %%
#finding unique values for each column
ds.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
#showing of what type of datatype for a column
ds.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#Here we can see the hotel types and its values, as it has unequal values i.e City Hotel has double values than Resort Hotels 
# By this we can say that it is a imbalanced data set
#we are analysing for each column which are necessary for us and getting unique values counts.

ds['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
ds['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %%
ds['lead_time'].value_counts()
# Out:
# lead_time
# 0      6345
# 1      3460
# 2      2069
# 3      1816
# 4      1715
#        ...
# 400       1
# 370       1
# 532       1
# 371       1
# 463       1
# Name: count, Length: 479, dtype: int64

# %%
ds['arrival_date_year'].value_counts()
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
ds['arrival_date_month'].value_counts()
# Out:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: count, dtype: int64

# %%
ds['arrival_date_week_number'].value_counts()
# Out:
# arrival_date_week_number
# 33    3580
# 30    3087
# 32    3045
# 34    3040
# 18    2926
# 21    2854
# 28    2853
# 17    2805
# 20    2785
# 29    2763
# 42    2756
# 31    2741
# 41    2699
# 15    2689
# 27    2664
# 25    2663
# 38    2661
# 23    2621
# 35    2593
# 39    2581
# 22    2546
# 24    2498
# 13    2416
# 16    2405
# 19    2402
# 40    2397
# 26    2391
# 43    2352
# 44    2272
# 14    2264
# 37    2229
# 8     2216
# 36    2167
# 10    2149
# 9     2117
# 7     2109
# 12    2083
# 11    2070
# 45    1941
# 53    1816
# 49    1782
# 47    1685
# 46    1574
# 6     1508
# 50    1505
# 48    1504
# 4     1487
# 5     1387
# 3     1319
# 2     1218
# 52    1195
# 1     1047
# 51     933
# Name: count, dtype: int64

# %%
ds['arrival_date_day_of_month'].value_counts()
# Out:
# arrival_date_day_of_month
# 17    4406
# 5     4317
# 15    4196
# 25    4160
# 26    4147
# 9     4096
# 12    4087
# 16    4078
# 2     4055
# 19    4052
# 20    4032
# 18    4002
# 24    3993
# 28    3946
# 8     3921
# 3     3855
# 30    3853
# 6     3833
# 14    3819
# 27    3802
# 21    3767
# 4     3763
# 13    3745
# 7     3665
# 1     3626
# 23    3616
# 11    3599
# 22    3596
# 29    3580
# 10    3575
# 31    2208
# Name: count, dtype: int64

# %%
ds['stays_in_weekend_nights'].value_counts()
# Out:
# stays_in_weekend_nights
# 0     51998
# 2     33308
# 1     30626
# 4      1855
# 3      1259
# 6       153
# 5        79
# 8        60
# 7        19
# 9        11
# 10        7
# 12        5
# 13        3
# 16        3
# 14        2
# 18        1
# 19        1
# Name: count, dtype: int64

# %%
ds['stays_in_week_nights'].value_counts()
# Out:
# stays_in_week_nights
# 2     33684
# 1     30310
# 3     22258
# 5     11077
# 4      9563
# 0      7645
# 6      1499
# 10     1036
# 7      1029
# 8       656
# 9       231
# 15       85
# 11       56
# 19       44
# 12       42
# 20       41
# 14       35
# 13       27
# 16       16
# 21       15
# 22        7
# 25        6
# 18        6
# 30        5
# 17        4
# 24        3
# 40        2
# 33        1
# 42        1
# 50        1
# 32        1
# 26        1
# 34        1
# 35        1
# 41        1
# Name: count, dtype: int64

# %%
ds['adults'].value_counts()
# Out:
# adults
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 27        2
# 20        2
# 5         2
# 40        1
# 50        1
# 55        1
# 6         1
# 10        1
# Name: count, dtype: int64

# %%
ds['children'].value_counts()
# Out:
# children
# 0.0     110796
# 1.0       4861
# 2.0       3652
# 3.0         76
# 10.0         1
# Name: count, dtype: int64

# %%
ds['babies'].value_counts()
# Out:
# babies
# 0     118473
# 1        900
# 2         15
# 10         1
# 9          1
# Name: count, dtype: int64

# %%
ds['meal'].value_counts()
# Out:
# meal
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: count, dtype: int64

# %%
ds['country'].value_counts()
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
ds['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
ds['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
ds['is_repeated_guest'].value_counts()
# Out:
# is_repeated_guest
# 0    115580
# 1      3810
# Name: count, dtype: int64

# %%
ds['previous_cancellations'].value_counts()
# Out:
# previous_cancellations
# 0     112906
# 1       6051
# 2        116
# 3         65
# 24        48
# 11        35
# 4         31
# 26        26
# 25        25
# 6         22
# 19        19
# 5         19
# 14        14
# 13        12
# 21         1
# Name: count, dtype: int64

# %%
ds['previous_bookings_not_canceled'].value_counts()
# Out:
# previous_bookings_not_canceled
# 0     115770
# 1       1542
# 2        580
# 3        333
# 4        229
# 5        181
# 6        115
# 7         88
# 8         70
# 9         60
# 10        53
# 11        43
# 12        37
# 13        30
# 14        28
# 15        21
# 16        20
# 25        17
# 17        16
# 18        14
# 19        13
# 20        12
# 21        12
# 22        10
# 24         9
# 27         9
# 26         7
# 28         7
# 23         7
# 29         6
# 30         4
# 31         2
# 32         2
# 58         2
# 48         2
# 44         2
# 62         1
# 56         1
# 57         1
# 59         1
# 60         1
# 61         1
# 65         1
# 63         1
# 64         1
# 66         1
# 67         1
# 68         1
# 69         1
# 70         1
# 71         1
# 54         1
# 55         1
# 36         1
# 53         1
# 41         1
# 33         1
# 34         1
# 35         1
# 37         1
# 38         1
# 39         1
# 40         1
# 42         1
# ...

# %%
ds['reserved_room_type'].value_counts()
# Out:
# reserved_room_type
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64

# %%
ds['assigned_room_type'].value_counts()
# Out:
# assigned_room_type
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: count, dtype: int64

# %%
ds['booking_changes'].value_counts()
# Out:
# booking_changes
# 0     101314
# 1      12701
# 2       3805
# 3        927
# 4        376
# 5        118
# 6         63
# 7         31
# 8         17
# 9          8
# 10         6
# 13         5
# 14         5
# 15         3
# 16         2
# 17         2
# 12         2
# 11         2
# 20         1
# 21         1
# 18         1
# Name: count, dtype: int64

# %%
ds['booking_changes'].unique
# Out:
# <bound method Series.unique of 0         3
# 1         4
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: booking_changes, Length: 119390, dtype: int64>

# %%
ds['deposit_type'].value_counts()
# Out:
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64

# %%
ds['agent'].value_counts()
# Out:
# agent
# 9.0      31961
# 240.0    13922
# 1.0       7191
# 14.0      3640
# 7.0       3539
#          ...
# 289.0        1
# 432.0        1
# 265.0        1
# 93.0         1
# 304.0        1
# Name: count, Length: 333, dtype: int64

# %%
ds['days_in_waiting_list'].value_counts()
# Out:
# days_in_waiting_list
# 0      115692
# 39        227
# 58        164
# 44        141
# 31        127
#         ...
# 116         1
# 109         1
# 37          1
# 89          1
# 36          1
# Name: count, Length: 128, dtype: int64

# %%
ds['customer_type'].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
ds['adr'].value_counts()
# Out:
# adr
# 62.00     3754
# 75.00     2715
# 90.00     2473
# 65.00     2418
# 0.00      1959
#           ...
# 89.43        1
# 63.07        1
# 55.69        1
# 49.51        1
# 157.71       1
# Name: count, Length: 8879, dtype: int64

# %%
ds['required_car_parking_spaces'].value_counts()
# Out:
# required_car_parking_spaces
# 0    111974
# 1      7383
# 2        28
# 3         3
# 8         2
# Name: count, dtype: int64

# %%
ds['total_of_special_requests'].value_counts()
# Out:
# total_of_special_requests
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: count, dtype: int64

# %%
ds['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
ds['reservation_status_date'].value_counts()
# Out:
# reservation_status_date
# 10/21/2015    1461
# 07-06-2015     805
# 11/25/2016     790
# 01-01-2015     763
# 1/18/2016      625
#               ...
# 2/27/2015        1
# 4/25/2015        1
# 03-11-2015       1
# 6/14/2015        1
# 02-12-2015       1
# Name: count, Length: 926, dtype: int64

# %%
# dealing for the coulumn which are some undefined and assigning it to the any one of the column values to analyse the results.
ds['meal'].replace('Undefined','sc',inplace=True)

# %%
#we can see there is no undefined values in the column
ds['meal'].value_counts()
# Out:
# meal
# BB    92310
# HB    14463
# SC    10650
# sc     1169
# FB      798
# Name: count, dtype: int64

# %%
#treating for the undefined value
ds['market_segment'].replace('Undefined','Groups',inplace=True)

# %%
ds['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19813
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Name: count, dtype: int64

# %%
#treating for the udefined values
ds['distribution_channel'].replace('Undefined','Corporate',inplace=True)

# %%
ds['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6682
# GDS            193
# Name: count, dtype: int64

# %%
#treating for no deposit values
ds['deposit_type'].replace('No Deposit','Refundable',inplace=True)

# %%
ds['deposit_type'].value_counts()
# Out:
# deposit_type
# Refundable    104803
# Non Refund     14587
# Name: count, dtype: int64

# %%
#treating for the No-show values
ds['reservation_status'].replace('No-Show','Canceled',inplace=True)

# %%
ds['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     44224
# Name: count, dtype: int64

# %%
#As we can see in the below column the date format was not correctly arranged and they are in improper order, so by using lambda function we are converting it to the string type and m-d-y format for a column.
ds['reservation_status_date'] = ds['reservation_status_date'].apply(lambda x: pd.to_datetime(x).strftime('%m-%d-%Y'))

# %%
# to see 100 rows
pd.set_option('display.max.rows',100)
ds.sample(100)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 4292    Resort Hotel            1        118               2016
# 62712     City Hotel            1         46               2017
# 374     Resort Hotel            1         81               2015
# 38143   Resort Hotel            0        171               2017
# 17438   Resort Hotel            0         11               2015
# 107268    City Hotel            0         69               2017
# 40363     City Hotel            0        132               2015
# 117530    City Hotel            0          2               2017
# 84362     City Hotel            0         36               2016
# 118859    City Hotel            0        103               2017
# 20998   Resort Hotel            0         61               2016
# 3747    Resort Hotel            1        113               2016
# 51575     City Hotel            1         95               2016
# 107646    City Hotel            0        211               2017
# ...

# %%
#checking whether the null values present in the data or not, and it is showing True which means there is null values preent.
ds.isnull().values.any()
# Out:
# True

# %%
# plotting  heatmap for the null values present in the data.
#setting of the figure size to see maximum content in the graph.
plt.figure(figsize=(25,20))
#passing the null values for plotting
sns.heatmap(ds.isnull())
#for showing or displaying of the graph
plt.show()

# %%
#listing out the total null values for each column
ds.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             488
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %% [markdown]
# # Data Cleaning

# %%
#dropping the unnecessary columns which are not useful for the further use and to improve or make precise data.
ds.drop(columns=['reserved_room_type','assigned_room_type','MO_YR','CPI_AVG','INFLATION','INFLATION_CHG','CSMR_SENT','UNRATE','INTRSRT','GDP','FUEL_PRCS','CPI_HOTELS','US_GINI','DIS_INC'], inplace=True)

# %%
#by displaying the rows we can see there are some null values present in the data
ds
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# lambda function that takes each column x, finds its mode (most frequent value), and fills the missing values (fillna) with this mode value (x.mode()[0]).
ds= ds.apply(lambda x: x.fillna(x.mode()[0]))

# %%
# we can see there are no null values present in the data.
ds.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# ...

# %%
#checking the data by displaying the rows whether any null or special values are visible or not.
ds
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#after dropping the unwanted columns we can able to see only 29 columns
ds.shape
# Out:
# (119390, 29)

# %%
#checking the datatype for the columns before training the model as it needs only integer format.
ds.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# deposit_type                       object
# agent                             float64
# ...

# %%
sns.countplot(data=ds, x='hotel')
plt.title("Distribution of Hotel Types")
plt.xlabel("Hotel Type")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(data=ds, x='is_canceled')
plt.title("Distribution of Canceled Bookings")
plt.xlabel("Cancellation Status (0: Not Canceled, 1: Canceled)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=ds, x='market_segment')
plt.title("Distribution of Market Segments")
plt.xlabel("Market Segment")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(ds['lead_time'], bins=30)
plt.title("Distribution of Lead Time")
plt.xlabel("Lead Time")
plt.ylabel("Count")
plt.show()

# %%
sns.barplot(data=ds, x='hotel', y='adr')
plt.title("Average Daily Rate (ADR) by Hotel Type")
plt.xlabel("Hotel Type")
plt.ylabel("Average Daily Rate (ADR)")
plt.show()

# %%
#plotting the countplot between hotels by which the more no of people are choosing which type of hotel.
sns.countplot(data=ds,x='hotel')
plt.title("Type of Hotel People choosing")
plt.show()

# %%
#plotting the countplot between the persons cancelled and also the repeated guest are arriving.
sns.countplot(data=ds,x='is_canceled',hue='is_repeated_guest')
#display of the title
plt.title("Cancellation Frequency by Guest Type")
#showing the graph
plt.show()

# %%
#plotting the graph of hotel type and guest type
sns.countplot(data=ds,x='hotel',hue='is_repeated_guest')
#for the displaying title
plt.title("Cancellation Frequency by Hotel Type and Guest Type")
#showing the graph
plt.show()

# %%
#displaying of the columns
ds.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'booking_changes', 'deposit_type',
#        'agent', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# displaying the datatypes for each column and converting it into integer format.
ds.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# deposit_type                       object
# agent                             float64
# ...

# %%
#Label encoding is a common technique used in data preprocessing, especially in machine learning workflows, for the conversion of category values to numerical values for training model.
#below are the categorical columns used for conversion into numeric types.
ds['hotel']=ds['hotel'].astype('category')
ds['hotel']=ds['hotel'].cat.codes

ds['arrival_date_month']=ds['arrival_date_month'].astype('category')
ds['arrival_date_month']=ds['arrival_date_month'].cat.codes

ds['meal']=ds['meal'].astype('category')
ds['meal']=ds['meal'].cat.codes

ds['country']=ds['country'].astype('category')
ds['country']=ds['country'].cat.codes

ds['market_segment']=ds['market_segment'].astype('category')
ds['market_segment']=ds['market_segment'].cat.codes

ds['distribution_channel']=ds['distribution_channel'].astype('category')
ds['distribution_channel']=ds['distribution_channel'].cat.codes

ds['deposit_type']=ds['deposit_type'].astype('category')
ds['deposit_type']=ds['deposit_type'].cat.codes

ds['customer_type']=ds['customer_type'].astype('category')
ds['customer_type']=ds['customer_type'].cat.codes

ds['reservation_status']=ds['reservation_status'].astype('category')
ds['reservation_status']=ds['reservation_status'].cat.codes


#we have to string of object type and we have to convert it to the date_time format
ds['reservation_status_date'] = pd.to_datetime(ds['reservation_status_date'])

# %%
 #as we can see  all the columns are converted into numeric.
ds
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0           1            0        342               2015                   5
# 1           1            0        737               2015                   5
# 2           1            0          7               2015                   5
# 3           1            0         13               2015                   5
# 4           1            0         14               2015                   5
# ...       ...          ...        ...                ...                 ...
# 119385      0            0         23               2017                   1
# 119386      0            0        102               2017                   1
# 119387      0            0         34               2017                   1
# 119388      0            0        109               2017                   1
# 119389      0            0        205               2017                   1
#
# ...

# %%
#showing column datatypes
ds.dtypes
# Out:
# hotel                                       int8
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                          int8
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                        int8
# country                                    int16
# market_segment                              int8
# distribution_channel                        int8
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
#As the column type present in datetime, it means that is not present integer format.
#we have to convert it into integer.
# Custom function to convert datetime to custom integer representation
def custom_int_representation(dt):
    return dt.year + dt.month  # Combine year and month into a single integer

# Apply custom function to 'datetime' column
ds['reservation_status_date'] = ds['reservation_status_date'].apply(custom_int_representation)

# showing the DataFrame
print(ds)
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0           1            0        342               2015                   5
# 1           1            0        737               2015                   5
# 2           1            0          7               2015                   5
# 3           1            0         13               2015                   5
# 4           1            0         14               2015                   5
# ...       ...          ...        ...                ...                 ...
# 119385      0            0         23               2017                   1
# 119386      0            0        102               2017                   1
# 119387      0            0         34               2017                   1
# 119388      0            0        109               2017                   1
# 119389      0            0        205               2017                   1
#
# ...

# %%
#all columns are converted it into integer type and it is ready for to train a model.
ds.dtypes
# Out:
# hotel                                int8
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                   int8
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                                 int8
# country                             int16
# market_segment                       int8
# distribution_channel                 int8
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# deposit_type                         int8
# agent                             float64
# ...

# %% [markdown]
# # Data Splitting

# %%
#splitting the columns into dependent and independent variables
#x--independent variable
#y--dependent variable

x=ds.drop(['is_canceled'],axis=1)
y=ds[['is_canceled']]

# %%
#It is a fundamental tool in machine learning used for splitting a dataset into training and testing sets. This process is essential for model training, validation, and evaluation.
from sklearn.model_selection import train_test_split

# %%
#The primary purpose of train_test_split is to create two separate datasets:
#------Training Dataset: Used to train the machine learning model.
#------Testing Dataset: Used to evaluate the trained model's performance on unseen data.
#x--The feature matrix containing input features used to train and test the model.
#y--The target variable (or label) that the model aims to predict.
#test_size-----Common values range from 0.2 (20% for testing). The remaining data is used for training.
# random_state-----optional parameter used for getting testing data of equal size for every time.
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#x_train typically represents the training set of features (independent variables) in a machine learning mode
x_train
# Out:
#         hotel  lead_time  arrival_date_year  arrival_date_month  \
# 67702       0         64               2017                   8
# 115851      0         34               2017                   5
# 57345       0          8               2016                  11
# 11622       1        251               2017                   8
# 33333       1         23               2017                   3
# ...       ...        ...                ...                 ...
# 76820       0          2               2016                   5
# 110268      0         91               2017                   0
# 103694      0         74               2016                   2
# 860         1        130               2015                   1
# 15795       1         16               2015                   5
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 67702                         18                          6
# 115851                        28                         10
# ...

# %%
#y_train typically represents the training set of target variables (dependent variables or response variables) in a machine learning model
y_train
# Out:
#         is_canceled
# 67702             1
# 115851            0
# 57345             1
# 11622             1
# 33333             0
# ...             ...
# 76820             0
# 110268            0
# 103694            0
# 860               1
# 15795             0
#
# [95512 rows x 1 columns]

# %%
#These features represent the input data that the model will use to make predictions
x_test
# Out:
#         hotel  lead_time  arrival_date_year  arrival_date_month  \
# 30946       1        203               2016                   2
# 40207       0         82               2015                   5
# 103708      0         25               2016                   2
# 85144       0          1               2016                   7
# 109991      0         70               2017                   0
# ...       ...        ...                ...                 ...
# 48376       0        251               2016                   7
# 19712       1        152               2015                   2
# 32188       1         40               2017                   4
# 92983       0        109               2016                   5
# 50036       0        169               2016                   0
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 30946                         49                          2
# 40207                         29                         16
# ...

# %%
#y_test typically represents the testing set of target variables (dependent variables or response variables) in a machine learning model
y_test
# Out:
#         is_canceled
# 30946             0
# 40207             1
# 103708            0
# 85144             0
# 109991            0
# ...             ...
# 48376             1
# 19712             0
# 32188             0
# 92983             0
# 50036             1
#
# [23878 rows x 1 columns]

# %%
ds.dtypes
# Out:
# hotel                                int8
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                   int8
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                                 int8
# country                             int16
# market_segment                       int8
# distribution_channel                 int8
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# deposit_type                         int8
# agent                             float64
# ...

# %% [markdown]
# # Model Training

# %%
#This line imports the Linear Regression model from scikit-learn's linear_model module. Linear Regression is a supervised learning algorithm used for regression tasks, where the goal is to predict a continuous numerical value
from sklearn.linear_model import LinearRegression
#This line initializes a Linear Regression model object named model
model=LinearRegression()
#This line trains the Linear Regression model using the training data.
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#         hotel  lead_time  arrival_date_year  arrival_date_month  \
# 30946       1        203               2016                   2
# 40207       0         82               2015                   5
# 103708      0         25               2016                   2
# 85144       0          1               2016                   7
# 109991      0         70               2017                   0
# ...       ...        ...                ...                 ...
# 48376       0        251               2016                   7
# 19712       1        152               2015                   2
# 32188       1         40               2017                   4
# 92983       0        109               2016                   5
# 50036       0        169               2016                   0
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 30946                         49                          2
# 40207                         29                         16
# ...

# %% [markdown]
# # Predicting Score

# %%
#This method takes the testing set of features (x_test) as input and returns the predicted output values based on the learned patterns from the training data.
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[ 4.66293670e-15],
#        [ 1.00000000e+00],
#        [-2.22044605e-15],
#        ...,
#        [ 3.77475828e-15],
#        [-2.88657986e-15],
#        [ 1.00000000e+00]])

# %%
#indicates that the model perfectly predicts the target variable.

# %% [markdown]
# # Model Evaluation

# %%
#The model.score(x_test, y_test) method in scikit-learn calculates the accuracy or R2(coefficient of determination) score of a machine learning model when evaluated on the testing data (x_test and y_test)
model.score(x_test,y_test)
# Out:
# 1.0

# %%
#If model is a regression model (such as Linear Regression), model.score(x_test, y_test) returns the R2score, also known as the coefficient of determination.
#R2 = 1 indicates that the model perfectly predicts the target variable.
#R2= 0 indicates that the model does not explain any variability in the target variable beyond the mean.
#R2 < 0 suggests that the model is performing worse than predicting the mean value of the target variable.
from sklearn.metrics import mean_squared_error, r2_score
mse=mean_squared_error(y_test,y_pred)
r_squared = r2_score(y_test, y_pred)

# %% [markdown]
# # Interpretation of Results

# %%
#for printing the values to know the model how best it is performing
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared: {r_squared:.2f}")
# Out:
# Mean Squared Error (MSE): 0.00
# R-squared: 1.00

# %%
#from above score we can say the model is predicting well and good

# %% [markdown]
# # Training Another model

# %%
#choosing another model
#It is a imbalanced dataset and target variable is of binary format
#we an also consider the other model(LogisticRegression)

# %%
##This line imports the Logistic Regression model from scikit-learn's linear_model module. Logistic Regression is a supervised learning algorithm used for regression tasks, where the goal is to predict a continuous numerical value
from sklearn.linear_model import LogisticRegression

# %%
#This line initializes a Logistic Regression model object named lr

lr=LogisticRegression()

#This line trains the Logistic Regression model using the training data.

lr.fit(x_train,y_train)
# Out:
# C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\akhil\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Predicting Model

# %%
##This method takes the testing set of features (x_test) as input and returns the predicted output values based on the learned patterns from the training data.

y_pred_lr = lr.predict(x_test)

# %% [markdown]
# # Model Score

# %%
#This line imports the accuracy_score metric from scikit-learn's metrics module. 
#accuracy_score is used to compute the accuracy of a classification model.
from sklearn.metrics import accuracy_score
#This line uses the trained Logistic Regression model (lr) to predict the target values (y_pred_test) based on the features in the testing data (x_test).
y_pred_test = lr.predict(x_test)


#This line calculates the accuracy of the model on the testing data. It compares the predicted values (y_pred_test) with the actual target values (y_test) and computes the percentage of correct predictions.
lr_accuracy_test = accuracy_score(y_test, y_pred_test)
#The accuracy score is then rounded to two decimal places and printed as a percentage.
print(f"Test Accuracy: {round(lr_accuracy_test * 100,2)}%")

#This line uses the trained Logistic Regression model (lr) to predict the target values (y_pred_train) based on the features in the training data (x_train).
y_pred_train = lr.predict(x_train)

#This line calculates the accuracy of the model on the training data. It compares the predicted values (y_pred_train) with the actual target values (y_train) and computes the percentage of correct predictions.
lr_accuracy_train = accuracy_score(y_train, y_pred_train)
#The accuracy score is then rounded to two decimal places and printed as a percentage.
print(f"Train Accuracy: {round(lr_accuracy_train * 100,2)}%")
# Out:
# Test Accuracy: 87.01%
# Train Accuracy: 87.07%

# %% [markdown]
# # Interpretation Of Results

# %%
#The training accuracy represents how well the model fits the training data.
#a very high training accuracy (almost close to 100%) can also be a sign of overfitting, where the model memorizes the training data but may not generalize well to new, unseen data.

# %%
#The testing accuracy represents how well the model generalizes to new, unseen data (testing data).
#Ideally, you want the testing accuracy to be high, indicating that the model performs well on data it hasn't seen during training.

# %%
#On the other hand, if both the training and testing accuracies are similar and reasonably high, it suggests that the model is performing well and can generalize to unseen data effectively.

# %% [markdown]
# # overall results

# %%
# comparing by taking two models
#   1)Multi-linear regression 
#      it gives the score as 100% as it is predicting well and good by model.

#   2)Logistic Regression
#      it gives the score almost to 100% it also a better model
#both the scores are good and well predicted by the models
#by comparing two models we can say Multi_linear regression is well and good
#we can also perform other model prediction on this data such as Decision_tree, Random_forest etc..
